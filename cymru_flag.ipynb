# %%
from PIL import Image;
import requests;
from io import BytesIO;


res = requests.get('https://i.redd.it/413vnrc1izq81.png');
im = Image.open(BytesIO(res.content));
pixels = im.load();

text_colour = (0, 0, 0, 255);

def print_1(x, y):
  pixels[x+0, y+0] = text_colour;
  pixels[x+0, y+1] = text_colour;
  pixels[x+0, y+2] = text_colour;
  pixels[x+0, y+3] = text_colour;
  pixels[x+0, y+4] = text_colour;
  return 2;

def print_2(x, y):
  pixels[x+0, y+0] = text_colour;
  pixels[x+1, y+0] = text_colour;
  pixels[x+2, y+0] = text_colour;
  pixels[x+2, y+1] = text_colour;
  pixels[x+2, y+2] = text_colour;
  pixels[x+1, y+2] = text_colour;
  pixels[x+0, y+2] = text_colour;
  pixels[x+0, y+3] = text_colour;
  pixels[x+0, y+4] = text_colour;
  pixels[x+1, y+4] = text_colour;
  pixels[x+2, y+4] = text_colour;
  return 4;

def print_3(x, y):
  pixels[x+0, y+0] = text_colour;
  pixels[x+1, y+0] = text_colour;
  pixels[x+2, y+0] = text_colour;
  pixels[x+0, y+2] = text_colour;
  pixels[x+1, y+2] = text_colour;
  pixels[x+2, y+2] = text_colour;
  pixels[x+0, y+4] = text_colour;
  pixels[x+1, y+4] = text_colour;
  pixels[x+2, y+4] = text_colour;
  pixels[x+2, y+1] = text_colour;
  pixels[x+2, y+3] = text_colour;
  return 4;

def print_4(x, y):
  pixels[x+0, y+0] = text_colour;
  pixels[x+0, y+1] = text_colour;
  pixels[x+0, y+2] = text_colour;
  pixels[x+1, y+2] = text_colour;
  pixels[x+2, y+0] = text_colour;
  pixels[x+2, y+1] = text_colour;
  pixels[x+2, y+2] = text_colour;
  pixels[x+2, y+3] = text_colour;
  pixels[x+2, y+4] = text_colour;
  return 4;

def print_5(x, y):
  pixels[x+0, y+0] = text_colour;
  pixels[x+1, y+0] = text_colour;
  pixels[x+2, y+0] = text_colour;
  pixels[x+0, y+1] = text_colour;
  pixels[x+2, y+2] = text_colour;
  pixels[x+1, y+2] = text_colour;
  pixels[x+0, y+2] = text_colour;
  pixels[x+2, y+3] = text_colour;
  pixels[x+0, y+4] = text_colour;
  pixels[x+1, y+4] = text_colour;
  pixels[x+2, y+4] = text_colour;
  return 4;

def print_6(x, y):
  pixels[x+0, y+0] = text_colour;
  pixels[x+0, y+1] = text_colour;
  pixels[x+0, y+2] = text_colour;
  pixels[x+0, y+3] = text_colour;
  pixels[x+0, y+4] = text_colour;
  pixels[x+2, y+0] = text_colour;
  pixels[x+2, y+2] = text_colour;
  pixels[x+2, y+3] = text_colour;
  pixels[x+2, y+4] = text_colour;
  pixels[x+1, y+0] = text_colour;
  pixels[x+1, y+2] = text_colour;
  pixels[x+1, y+4] = text_colour;
  return 4;

def print_7(x, y):
  pixels[x+0, y+0] = text_colour;
  pixels[x+1, y+0] = text_colour;
  pixels[x+2, y+0] = text_colour;
  pixels[x+2, y+1] = text_colour;
  pixels[x+2, y+2] = text_colour;
  pixels[x+2, y+3] = text_colour;
  pixels[x+2, y+4] = text_colour;
  return 4;

def print_8(x, y):
  pixels[x+0, y+0] = text_colour;
  pixels[x+0, y+1] = text_colour;
  pixels[x+0, y+2] = text_colour;
  pixels[x+0, y+3] = text_colour;
  pixels[x+0, y+4] = text_colour;
  pixels[x+2, y+0] = text_colour;
  pixels[x+2, y+1] = text_colour;
  pixels[x+2, y+2] = text_colour;
  pixels[x+2, y+3] = text_colour;
  pixels[x+2, y+4] = text_colour;
  pixels[x+1, y+0] = text_colour;
  pixels[x+1, y+2] = text_colour;
  pixels[x+1, y+4] = text_colour;
  return 4;

def print_9(x, y):
  pixels[x+0, y+0] = text_colour;
  pixels[x+0, y+1] = text_colour;
  pixels[x+0, y+2] = text_colour;
  pixels[x+2, y+0] = text_colour;
  pixels[x+2, y+1] = text_colour;
  pixels[x+2, y+2] = text_colour;
  pixels[x+2, y+3] = text_colour;
  pixels[x+2, y+4] = text_colour;
  pixels[x+1, y+0] = text_colour;
  pixels[x+1, y+2] = text_colour;
  return 4;

def print_0(x, y):
  pixels[x+0, y+0] = text_colour;
  pixels[x+0, y+1] = text_colour;
  pixels[x+0, y+2] = text_colour;
  pixels[x+0, y+3] = text_colour;
  pixels[x+0, y+4] = text_colour;
  pixels[x+2, y+0] = text_colour;
  pixels[x+2, y+1] = text_colour;
  pixels[x+2, y+2] = text_colour;
  pixels[x+2, y+3] = text_colour;
  pixels[x+2, y+4] = text_colour;
  pixels[x+1, y+0] = text_colour;
  pixels[x+1, y+4] = text_colour;
  return 4;

def print(x, y, n):
  if n == 0:
    return print_0(x, y);
  if n == 1:
    return print_1(x, y);
  if n == 2:
    return print_2(x, y);
  if n == 3:
    return print_3(x, y);
  if n == 4:
    return print_4(x, y);
  if n == 5:
    return print_5(x, y);
  if n == 6:
    return print_6(x, y);
  if n == 7:
    return print_7(x, y);
  if n == 8:
    return print_8(x, y);
  if n == 9:
    return print_9(x, y);
  
  return 0;

for y in range(28):
  for x in range(48):

    # Each square is 15 x 15 and starts at offset 16:16
    pos = (15*x + 16, 15*y + 16);

    # 75, 119 is the top left position of the (welsh) flag
    index = (75 + x, 119 + y);

    # Convert coordinate to string
    # draw each digit
    # move cursor along width of digit
    x_str = str(index[0]);
    x_offset = 0;
    for c in x_str:
      digit = int(c);
      width = print(pos[0] + x_offset, pos[1], digit);
      x_offset = x_offset + width;

    y_str = str(index[1]);
    y_offset = 0;
    for c in y_str:
      digit = int(c);
      width = print(pos[0] + y_offset, pos[1] + 6, digit);
      y_offset = y_offset + width;
      
display(im);
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=750x450 at 0x7F2FF21EDCD0>
